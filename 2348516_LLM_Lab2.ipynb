# %%
# !pip install python-dotenv
# !pip install langchain
# !pip install langchain-groq
# Out:
# Collecting python-dotenv
#   Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.0.1
# Collecting langchain
#   Downloading langchain-0.2.7-py3-none-any.whl (983 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.6/983.6 kB 15.4 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.0.31)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (3.9.5)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (4.0.3)
# Collecting langchain-core<0.3.0,>=0.2.12 (from langchain)
#   Downloading langchain_core-0.2.13-py3-none-any.whl (357 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 357.9/357.9 kB 26.7 MB/s eta 0:00:00
# Collecting langchain-text-splitters<0.3.0,>=0.2.0 (from langchain)
#   Downloading langchain_text_splitters-0.2.2-py3-none-any.whl (25 kB)
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain)
#   Downloading langsmith-0.1.85-py3-none-any.whl (127 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 kB 11.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (1.25.2)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.8.0)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (8.4.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<0.3.0,>=0.2.12->langchain)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3.0,>=0.2.12->langchain) (24.1)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.2.0,>=0.1.17->langchain)
#   Downloading orjson-3.10.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (141 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.1/141.1 kB 7.5 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (2.20.0)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2024.6.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.3)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.12->langchain)
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Installing collected packages: orjson, jsonpointer, jsonpatch, langsmith, langchain-core, langchain-text-splitters, langchain
# Successfully installed jsonpatch-1.33 jsonpointer-3.0.0 langchain-0.2.7 langchain-core-0.2.13 langchain-text-splitters-0.2.2 langsmith-0.1.85 orjson-3.10.6
# Collecting langchain-groq
#   Downloading langchain_groq-0.1.6-py3-none-any.whl (14 kB)
# Collecting groq<1,>=0.4.1 (from langchain-groq)
#   Downloading groq-0.9.0-py3-none-any.whl (103 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.5/103.5 kB 4.6 MB/s eta 0:00:00
# Requirement already satisfied: langchain-core<0.3,>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from langchain-groq) (0.2.13)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from groq<1,>=0.4.1->langchain-groq) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from groq<1,>=0.4.1->langchain-groq) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from groq<1,>=0.4.1->langchain-groq)
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 8.8 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from groq<1,>=0.4.1->langchain-groq) (2.8.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from groq<1,>=0.4.1->langchain-groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from groq<1,>=0.4.1->langchain-groq) (4.12.2)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3,>=0.2.2->langchain-groq) (6.0.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3,>=0.2.2->langchain-groq) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.75 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3,>=0.2.2->langchain-groq) (0.1.85)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3,>=0.2.2->langchain-groq) (24.1)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3,>=0.2.2->langchain-groq) (8.4.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->groq<1,>=0.4.1->langchain-groq) (3.7)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->groq<1,>=0.4.1->langchain-groq) (1.2.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq) (2024.6.2)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq)
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 7.3 MB/s eta 0:00:00
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.4 MB/s eta 0:00:00
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3,>=0.2.2->langchain-groq) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.75->langchain-core<0.3,>=0.2.2->langchain-groq) (3.10.6)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.75->langchain-core<0.3,>=0.2.2->langchain-groq) (2.31.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->groq<1,>=0.4.1->langchain-groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->groq<1,>=0.4.1->langchain-groq) (2.20.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.75->langchain-core<0.3,>=0.2.2->langchain-groq) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.75->langchain-core<0.3,>=0.2.2->langchain-groq) (2.0.7)
# Installing collected packages: h11, httpcore, httpx, groq, langchain-groq
# Successfully installed groq-0.9.0 h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 langchain-groq-0.1.6

# %%
from dotenv import load_dotenv
from langchain.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_groq import ChatGroq
import os

# %%
load_dotenv()

# Retrieve the API key from the environment variable
api_key = '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'
# Print the API key to ensure it is loaded correctly (for debugging purposes, remove this in production)
print(api_key)
# Out:
# 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

# %%
model = ChatGroq(api_key = api_key ,model_name = 'llama3-8b-8192')

# %%
parser = StrOutputParser()
chain = model | parser
chain.invoke('what is table tennis')
# Out:
# "Table tennis, also known as ping-pong, is a fast-paced and exciting sport played on a table with small rackets and a lightweight ball. Here's a brief overview:\n\n**Objective:**\nThe objective of table tennis is to hit the ball back and forth with your opponent in a way that makes it difficult for them to return it. A match is usually played best two out of three or best three out of five games.\n\n**Equipment:**\n\n* **Table:** A rectangular table with a smooth surface, typically made of wood or composite materials, measuring 9 feet long, 5 feet wide, and 30 inches high.\n* **Racket:** A lightweight racket, also known as a paddle or bat, made of wood, plastic, or composite materials.\n* **Ball:** A lightweight, hollow, and celluloid ball with a diameter of 40 mm.\n\n**Basic rules:**\n\n* A match starts with a serve, where one player serves the ball by hitting it with their racket, allowing the ball to bounce on the opponent's side of the table.\n* The ball must bounce on the opponent's side of the table before being hit back.\n* Points are scored when a player fails to return the ball or makes an error, and the ball lands on their side of the table.\n* A game is won when a player leads by at least two points, unless the score is tied at 10-10, in which case the game continues until one player leads by two points.\n\n**Types of shots:**\n\n* **Forehand:** A shot hit by the player with their racket facing forward.\n* **Backhand:** A shot hit by the player with their racket facing backward.\n* **Loop:** A shot hit with a lot of spin, which makes the ball curve in mid-air.\n* **Smash:** A powerful shot hit downward, often used to finish off a rally.\n\n**Popular variations:**\n\n* **Singles:** One-on-one competition, where players take turns serving and playing.\n* **Doubles:** Two-on-two competition, where two players on each team take turns serving and playing.\n* **Team:** A variation played with teams of two or more players.\n\nTable tennis is an Olympic sport and is played at the professional and amateur levels worldwide. It's a great way to improve hand-eye coordination, reaction time, and strategic thinking while having fun and staying active."

# %% [markdown]
# Question Answering

# %%
template = (
    """
    you're question answering expert
answer : {answer}
"""
)

# %%
prompt = PromptTemplate.from_template(template=template)

# %%
chain =  prompt | model | parser

# %%
answer = """
tell me about table tennis
"""

# %%
result = chain.invoke({'answer':answer})
print(result)
# Out:
# Table tennis!
#
# Table tennis, also known as ping-pong, is a popular recreational and competitive sport played on a table with small rackets and a lightweight ball. Here are some interesting facts and information about table tennis:
#
# **History:** Table tennis originated in the 19th century in England, where it was played as an indoor game in the 1880s. It gained popularity in the 1920s and 1930s, and the first official World Championships were held in 1926.
#
# **Equipment:** A standard table tennis table is 9 feet (2.74 meters) long, 5 feet (1.52 meters) wide, and 30 inches (76 cm) high. The rackets (or paddles) are made of wood, composite materials, or carbon fiber, and the balls are made of celluloid or plastic. The balls are 40 mm in diameter and weigh 2.7 grams.
#
# **Objective:** The objective of table tennis is to hit the ball in such a way that your opponent cannot return it. Players take turns hitting the ball back and forth, trying to outmaneuver each other.
#
# **Styles:** There are several playing styles in table tennis, including:
#
# * **Forehand:** A player who specializes in hitting the ball with their forehand side.
# * **Backhand:** A player who specializes in hitting the ball with their backhand side.
# * **Penholder:** A player who holds the racket like a pen, with the wrist facing downwards.
# * **Chopper:** A player who specializes in playing defensive shots, often using a long paddle and a lot of spin.
#
# **Tactics:** Players use various tactics to outmaneuver their opponents, including:
#
# * **Spin:** Impressing spin on the ball to make it difficult for the opponent to return.
# * **Loop:** Hitting the ball high and deep to make the opponent stretch for it.
# * **Flick:** Hitting the ball with a lot of spin to make it curve and dip.
# * **Block:** Blocking the opponent's shot with the racket, often using a lot of spin.
#
# **Competitions:** Table tennis is an Olympic sport, with singles and doubles events for men and women. The International Table Tennis Federation (ITTF) is the governing body for the sport, and it organizes several international competitions, including the World Championships and the ITTF World Tour.
#
# **Popularity:** Table tennis is popular worldwide, with an estimated 300 million players globally. It's a popular recreational activity in many countries, and it's also played competitively at the amateur and professional levels.
#
# **Health benefits:** Table tennis is an excellent way to improve hand-eye coordination, reaction time, and overall physical fitness. It's also a low-impact sport, making it accessible to people of all ages and abilities.
#
# **Fun facts:**
#
# * The fastest recorded serve in table tennis was 140 km/h (87 mph).
# * The highest recorded score in a table tennis match was 21-0.
# * Table tennis is the most popular sport in the world, with an estimated 300 million players.
#
# I hope you found this information helpful! Do you have any specific questions about table tennis?

# %%
model = ChatGroq(api_key = api_key ,model_name = 'gemma-7b-it')
parser = StrOutputParser()
chain = model | parser
chain.invoke('what is table tennis')
# Out:
# "**Table tennis** is a racket sport that involves hitting a lightweight ball back and forth using paddles over a net. It is also known as ping-pong.\n\n**Gameplay:**\n\n- The game is played on a rectangular table with a net dividing it in half.\n- Two or four players hit the ball back and forth using their paddles.\n- The goal is to score points by hitting the ball so that it lands in your opponent's half or causes them to make a mistake.\n- Points are won by winning points, with the first player or team to reach 11 points winning the game.\n\n**Rules:**\n\n- The ball must be served into the opponent's half.\n- The paddle must not touch the ball twice in a row.\n- The ball must be hit below the waist level.\n- The ball must land in the playing area.\n\n**Equipment:**\n\n- Table tennis table\n- Net\n- Paddles\n- Ball\n\n**Skills:**\n\nTable tennis requires a combination of skills, including:\n\n- **Technique:** Proper grip, body posture, and paddle technique.\n- **Power:** Generating enough force to hit the ball with enough speed and spin.\n- **Control:** Accuracy and precision in hitting the ball.\n- **Spin:** Applying different spins to control the ball's trajectory and spin.\n\n**Popularity:**\n\nTable tennis is a popular sport enjoyed by people of all ages and abilities. It is often played in recreational leagues and tournaments. It is also a popular indoor activity for schools and communities.\n\n**Health Benefits:**\n\nPlaying table tennis offers several health benefits, including:\n\n- Improved hand-eye coordination\n- Increased reflexes\n- Reduced stress and anxiety\n- Improved cardiovascular health\n- Increased social interaction"

# %%
model = ChatGroq(api_key = api_key ,model_name = 'gemma2-9b-it')
parser = StrOutputParser()
chain = model | parser
chain.invoke('what is table tennis')
# Out:
# 'Table tennis, also known as ping-pong, is a sport played by two players (singles) or two pairs of players (doubles) on a rectangular table divided by a net. \n\n**Here\'s a breakdown:**\n\n* **Objective:** The objective is to hit a lightweight ball back and forth over the net using small paddles called "rackets" or "bats." Players score points by making their opponent miss the ball or hit it out of bounds.\n* **Gameplay:** Players take turns serving the ball, which must bounce once on their side of the table before going over the net. The receiving player must let the ball bounce once on their side before returning it. The rally continues until a player fails to return the ball correctly.\n* **Equipment:**\n    * **Table:** A rectangular table covered with a smooth, hard surface.\n    * **Net:** A net stretched across the middle of the table.\n    * **Ball:** A small, lightweight ball made of celluloid or plastic.\n    * **Racket:** A small wooden or composite paddle with a rubber surface.\n* **Rules:** There are numerous rules governing the game, including:\n    * Service rules (e.g., ball toss, contact point)\n    * Scoring system (e.g., points, games, matches)\n    * Fouls (e.g., hitting the ball before it bounces, touching the table with the racket)\n\n**Why People Enjoy Table Tennis:**\n\n* **Fast-paced and exciting:**  Table tennis is a highly dynamic sport with quick reflexes and strategic play.\n* **Accessible:** It can be played almost anywhere with a simple table and paddles.\n* **Social and fun:**  It\'s a great way to exercise and socialize with friends and family.\n* **Competitive:**  There are professional tournaments and leagues worldwide, offering a chance to compete at a high level.\n\n\nLet me know if you have any other questions about table tennis!\n'

# %% [markdown]
# From Gemini

# %% [markdown]
# ![Screenshot 2024-07-11 104930.png](data:image/png;base64,...)From Chatgpt

# %% [markdown]
# ![Screenshot 2024-07-11 105025.png](data:image/png;base64,...)
